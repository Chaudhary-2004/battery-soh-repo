# %% [markdown]
# # 01 — EDA (Exploratory Data Analysis)

# %%
import os
os.getcwd()
# Out:
# 'C:\\Users\\Shash\\Desktop\\PROJECT_ARJUN\\battery-soh-repo\\battery-soh-repo\\notebooks'

# %%
import pandas as pd
df = pd.read_csv('../DATA/Battery_RUL_with_features.csv')
df.head()
# Out:
#    Cycle_Index  Discharge Time (s)  Decrement 3.6-3.4V (s)  \
# 0            1             2595.30             1151.488500
# 1            2             7408.64             1172.512500
# 2            3             7393.76             1112.992000
# 3            4             7385.50             1080.320667
# 4            6            65022.75            29813.487000
#
#    Max. Voltage Dischar. (V)  Min. Voltage Charg. (V)  Time at 4.15V (s)  \
# 0                      3.670                    3.211           5460.001
# 1                      4.246                    3.220           5508.992
# 2                      4.249                    3.224           5508.993
# 3                      4.250                    3.225           5502.016
# 4                      4.290                    3.398           5480.992
#
#    Time constant current (s)  Charging time (s)   RUL  Voltage_Range  \
# 0                    6755.01           10777.82  1112          0.459
# ...

# %%
df.describe(include='all')
# Out:
#         Cycle_Index  Discharge Time (s)  Decrement 3.6-3.4V (s)  \
# count  15064.000000        15064.000000            15064.000000
# mean     556.155005         4581.273960             1239.784672
# std      322.378480        33144.012077            15039.589269
# min        1.000000            8.690000          -397645.908000
# 25%      271.000000         1169.310000              319.600000
# 50%      560.000000         1557.250000              439.239471
# 75%      833.000000         1908.000000              600.000000
# max     1134.000000       958320.370000           406703.768000
#
#        Max. Voltage Dischar. (V)  Min. Voltage Charg. (V)  Time at 4.15V (s)  \
# count               15064.000000             15064.000000       15064.000000
# mean                    3.908176                 3.577904        3768.336171
# std                     0.091003                 0.123695        9129.552477
# min                     3.043000                 3.022000        -113.584000
# ...

# %%
import pandas as pd
df.isna().mean().sort_values(ascending=False).head(20)  # top missingness
# Out:
# Delta_SOH                    0.000066
# Discharge Time (s)           0.000000
# Cycle_Index                  0.000000
# Max. Voltage Dischar. (V)    0.000000
# Min. Voltage Charg. (V)      0.000000
# Time at 4.15V (s)            0.000000
# Decrement 3.6-3.4V (s)       0.000000
# Time constant current (s)    0.000000
# Charging time (s)            0.000000
# Voltage_Range                0.000000
# RUL                          0.000000
# Discharge_Time_Norm          0.000000
# SOH                          0.000000
# Rolling_DischargeTime        0.000000
# Rolling_SOH                  0.000000
# dtype: float64

# %%
import matplotlib.pyplot as plt
if 'SOH' in df.columns:
    df['SOH'].hist(bins=30)
    plt.title('SOH distribution')
    plt.xlabel('SOH')
    plt.ylabel('count')
    plt.show()
